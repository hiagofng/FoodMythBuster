# %% [markdown]
# # FoodMythBuster — Data Exploration\n\nQuerying the staging layer to investigate whether "healthy" food labels align with NOVA classification.

# %%
import duckdb\n\ncon = duckdb.connect("../data/foodmythbuster.duckdb", read_only=True)\ncon.sql("SELECT count(*) AS total_products FROM staging.stg_products")
